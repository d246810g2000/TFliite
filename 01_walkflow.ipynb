# %% [markdown]
# # 01_walkflow
# * [1. Choose a model](#1.-Choose-a-model)
# * [2. Optimize your model](#2.-Optimize-your-model)
# * [3. Convert the model](#3.-Convert-the-model)
# * [4. Inference the model](#4.-Inference-the-model)

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## 1. Choose a model
#
#  * h5 file
#  * SavedModel

# %%
# Build a pre-trained model: h5 file, SavedModel
from tensorflow.keras.applications.mobilenet import MobileNet
model = MobileNet(weights='imagenet', include_top=True, input_shape=(224, 224, 3))

# Save to h5 file
model.save('model/mobilenet_keras_model.h5') 

# Save to SavedModel directory
tf.saved_model.save(model, 'model/mobilenet_saved_model')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model/mobilenet_saved_model/assets

# %% [markdown]
# ## 2. Optimize your model
#  * Post-training (請參考 02_post_training.ipynb)
#      - Quantization
#  * Aware-training (請參考 03_aware_training.ipynb)
#      - Quantization
#      - Pruning
#      - Clustering

# %% [markdown]
# ## 3. Convert the model

# %% [markdown]
# ### Command Line Tool
#  --output_file OUTPUT_FILE <br>
# <font color="red">&emsp;Full filepath of the output file.</font><br>
#  --saved_model_dir SAVED_MODEL_DIR <br>
# <font color="red">&emsp;Full path of the directory containing the SavedModel.</font><br>
#  --keras_model_file KERAS_MODEL_FILE <br>
# <font color="red">&emsp;Full filepath of HDF5 file containing tf.Keras model.</font><br>

# %%
# !tflite_convert --help
# Out:
# usage: tflite_convert [-h] --output_file OUTPUT_FILE
#                       (--saved_model_dir SAVED_MODEL_DIR | --keras_model_file KERAS_MODEL_FILE)
#
# Command line tool to run TensorFlow Lite Converter.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --output_file OUTPUT_FILE
#                         Full filepath of the output file.
#   --saved_model_dir SAVED_MODEL_DIR
#                         Full path of the directory containing the SavedModel.
#   --keras_model_file KERAS_MODEL_FILE
#                         Full filepath of HDF5 file containing tf.Keras model.

# %% [markdown]
# ### Converts a Keras model with Command Line Tool

# %%
# !tflite_convert \
  --keras_model_file=model/mobilenet_keras_model.h5 \
  --output_file=tflite_model/mobilenet.tflite
# Out:
# 2020-10-28 11:33:37.625403: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-28 11:33:37.674910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:37.690820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:37.693423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:37.696047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:37.696216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:37.697511: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:37.698661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:37.698922: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:37.700424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:37.701624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-10-28 11:33:37.705539: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-28 11:33:37.725661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1, 2, 3
# 2020-10-28 11:33:37.725914: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-10-28 11:33:37.734166: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3199710000 Hz
# 2020-10-28 11:33:37.734785: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562c23d00da0 executing computations on platform Host. Devices:
# 2020-10-28 11:33:37.734802: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2020-10-28 11:33:38.412490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:38.415433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:38.417583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:38.419713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:38.419764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:38.419779: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:38.419792: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:38.419805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:38.419818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:38.419831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-10-28 11:33:38.419845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-28 11:33:38.437494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1, 2, 3
# 2020-10-28 11:33:38.437531: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:38.446690: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-28 11:33:38.446703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1 2 3
# 2020-10-28 11:33:38.446710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y Y Y
# 2020-10-28 11:33:38.446715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N Y Y
# 2020-10-28 11:33:38.446719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   Y Y N Y
# 2020-10-28 11:33:38.446724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   Y Y Y N
# 2020-10-28 11:33:38.460118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 101 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2020-10-28 11:33:38.464651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10351 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:0c:00.0, compute capability: 6.1)
# 2020-10-28 11:33:38.469135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10351 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1)
# 2020-10-28 11:33:38.473603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10351 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1)
# 2020-10-28 11:33:38.475989: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x562c25327860 executing computations on platform CUDA. Devices:
# 2020-10-28 11:33:38.476003: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2020-10-28 11:33:38.476010: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (1): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2020-10-28 11:33:38.476015: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (2): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2020-10-28 11:33:38.476021: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (3): GeForce GTX 1080 Ti, Compute Capability 6.1
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# W1028 11:33:40.249202 140436174042880 hdf5_format.py:177] No training configuration found in save file: the model was *not* compiled. Compile it manually.
# 2020-10-28 11:33:40.764155: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 4
# 2020-10-28 11:33:40.764267: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2020-10-28 11:33:40.766556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:40.768678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:40.770810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:40.772950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:40.772999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:40.773015: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:40.773031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:40.773045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:40.773059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:40.773073: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-10-28 11:33:40.773088: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-28 11:33:40.789557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1, 2, 3
# 2020-10-28 11:33:40.789756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-28 11:33:40.789764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1 2 3
# 2020-10-28 11:33:40.789770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y Y Y
# 2020-10-28 11:33:40.789775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N Y Y
# 2020-10-28 11:33:40.789780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   Y Y N Y
# 2020-10-28 11:33:40.789785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   Y Y Y N
# 2020-10-28 11:33:40.799983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 101 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2020-10-28 11:33:40.802165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10351 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:0c:00.0, compute capability: 6.1)
# 2020-10-28 11:33:40.804327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10351 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1)
# 2020-10-28 11:33:40.806476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10351 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1)
# 2020-10-28 11:33:40.822289: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:716] Optimization results for grappler item: graph_to_optimize
# 2020-10-28 11:33:40.822304: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# 2020-10-28 11:33:40.822310: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-10-28 11:33:41.445554: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 4
# 2020-10-28 11:33:41.445679: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2020-10-28 11:33:41.447813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:41.449951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:41.452076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:41.454202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:41.454248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:41.454262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:41.454274: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:41.454287: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:41.454299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:41.454312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-10-28 11:33:41.454325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-28 11:33:41.470964: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1, 2, 3
# 2020-10-28 11:33:41.471151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-28 11:33:41.471160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1 2 3
# 2020-10-28 11:33:41.471167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y Y Y
# 2020-10-28 11:33:41.471172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N Y Y
# 2020-10-28 11:33:41.471177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   Y Y N Y
# 2020-10-28 11:33:41.471182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   Y Y Y N
# 2020-10-28 11:33:41.481393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 101 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2020-10-28 11:33:41.483545: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10351 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:0c:00.0, compute capability: 6.1)
# 2020-10-28 11:33:41.485710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10351 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1)
# 2020-10-28 11:33:41.487933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10351 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1)
# 2020-10-28 11:33:41.669904: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:716] Optimization results for grappler item: graph_to_optimize
# 2020-10-28 11:33:41.669941: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   constant folding: Graph size after: 254 nodes (-137), 392 edges (-137), time = 94.853ms.
# 2020-10-28 11:33:41.669947: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   constant folding: Graph size after: 254 nodes (0), 392 edges (0), time = 24.976ms.

# %% [markdown]
# ### Converts a SavedModel with Command Line Tool

# %%
# !tflite_convert \
  --saved_model_dir=model/mobilenet_saved_model  \
  --output_file=tflite_model/mobilenet.tflite
# Out:
# 2020-10-28 11:33:47.580393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-28 11:33:47.613521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:47.615685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:47.617832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:47.619970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:47.620186: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:47.621413: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:47.622499: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:47.622749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:47.624173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:47.625321: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020
I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   Y Y N Y
# 2020-10-28 11:33:53.261260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   Y Y Y N
# 2020-10-28 11:33:53.271418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 101 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.273571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10351 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:0c:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.275716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10351 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.277867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10351 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.317614: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:716] Optimization results for grappler item: graph_to_optimize
# 2020-10-28 11:33:53.317630: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   function_optimizer: Graph size after: 586 nodes (446), 1152 edges (1012), time = 19.633ms.
# 2020-10-28 11:33:53.317636: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   function_optimizer: function_optimizer did nothing. time = 0.321ms.
# 2020-10-28 11:33:53.948825: I tensorflow/core/grappler/devices.cc:55] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 4
# 2020-10-28 11:33:53.948958: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2020-10-28 11:33:53.951102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:04:00.0
# 2020-10-28 11:33:53.953245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0c:00.0
# 2020-10-28 11:33:53.955383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 2 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0e:00.0
# 2020-10-28 11:33:53.957515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 3 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:0f:00.0
# 2020-10-28 11:33:53.957566: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-10-28 11:33:53.957581: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-10-28 11:33:53.957596: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-10-28 11:33:53.957610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-10-28 11:33:53.957624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-10-28 11:33:53.957638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-10-28 11:33:53.957652: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-10-28 11:33:53.974036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1, 2, 3
# 2020-10-28 11:33:53.974218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-28 11:33:53.974227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1 2 3
# 2020-10-28 11:33:53.974234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y Y Y
# 2020-10-28 11:33:53.974239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N Y Y
# 2020-10-28 11:33:53.974244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 2:   Y Y N Y
# 2020-10-28 11:33:53.974250: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 3:   Y Y Y N
# 2020-10-28 11:33:53.984413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 101 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.986580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10351 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:0c:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.988718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10351 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1)
# 2020-10-28 11:33:53.990857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 10351 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1)
# 2020-10-28 11:33:54.258529: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:716] Optimization results for grappler item: graph_to_optimize
# 2020-10-28 11:33:54.258566: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   constant folding: Graph size after: 396 nodes (-137), 825 edges (-274), time = 156.152ms.
# 2020-10-28 11:33:54.258575: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:718]   constant folding: Graph size after: 396 nodes (0), 825 edges (0), time = 46.761ms.

# %% [markdown]
# ### Python API
# Convert a TensorFlow 2.x model using TensorFlow Lite converter: tf.lite.TFLiteConverter.
#  * Converts a Keras model
#      - tf.lite.TFLiteConverter.from_keras_model()
#  * Converts a SavedModel
#      - tf.lite.TFLiteConverter.from_saved_model() (recommended)
#  * Converts concrete functions
#      - tf.lite.TFLiteConverter.from_concrete_functions()

# %% [markdown]
# ### Converts a Keras model with Python API

# %%
# Load the model.
model = tf.keras.models.load_model('model/mobilenet_keras_model.h5')

# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('tflite_model/mobilenet.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Converts a SavedModel with Python API

# %%
# path to the SavedModel directory
saved_model_dir = 'model/mobilenet_saved_model'

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
tflite_model = converter.convert()

# Save the model.
with open('tflite_model/mobilenet.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ### Converts concrete functions with Python API

# %%
# Create a model using low-level tf.* APIs
class Squared(tf.Module):
    @tf.function
    def __call__(self, x):
        return tf.square(x)
model = Squared()
concrete_func = model.__call__.get_concrete_function(
    tf.TensorSpec(shape=[None, 1], dtype=tf.float32)
)

# %%
# Convert the model
converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func])
tflite_model = converter.convert()
# Save the model.
with open('tflite_model/concrete_functions.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ## 4. Inference the model

# %%
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="tflite_model/mobilenet.tflite")
interpreter.allocate_tensors()

# %%
# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
input_details
# Out:
# [{'name': 'input_1',
#   'index': 101,
#   'shape': array([  1, 224, 224,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)}]

# %%
output_details
# Out:
# [{'name': 'Identity',
#   'index': 0,
#   'shape': array([   1, 1000], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)}]

# %%
# Test the model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()

# %%
# The function 'tensor()' returns a pointer to the tensor.
output_data = interpreter.tensor(output_details[0]['index'])
print(output_data)
# Out:
# <function Interpreter.tensor.<locals>.<lambda> at 0x7f6c30ac3d08>

# %%
# The function 'get_tensor()' returns a copy of the tensor data.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [[2.17110355e-05 8.06244061e-05 6.94543472e-04 2.59275275e-05
#   1.04193052e-03 4.06472333e-04 1.92650768e-03 1.44019014e-05
#   4.60201627e-05 1.37082927e-04 1.58209703e-04 4.67627069e-05
#   3.87580396e-04 5.21293026e-04 6.67030516e-04 2.20626662e-03
#   5.20122063e-04 1.64278230e-04 4.05233307e-03 1.40845863e-04
#   7.00320015e-05 2.32152129e-03 1.08423072e-03 2.51309248e-03
#   1.23647624e-03 2.81769080e-05 4.13653870e-05 3.17835889e-04
#   1.90152969e-05 8.90031515e-05 1.68984152e-05 1.33654787e-04
#   1.75177975e-05 2.82391877e-04 2.06027972e-03 1.19738843e-05
